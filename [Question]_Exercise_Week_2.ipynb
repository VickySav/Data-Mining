# %% [markdown]
# ## Week 2
#
# Please print your name and your NIM.

# %%
# here
print('Tjok Istri Vicky Savitri - 0706022210027')
# Out:
# Tjok Istri Vicky Savitri - 0706022210027

# %% [markdown]
# ## Pandas

# %% [markdown]
# Please import the necessary library here.

# %%
# Import Library
import pandas as pd

# %% [markdown]
# <h1> Import Data

# %% [markdown]
# Please download the data from zip Elearn. <br>
# then put it on your own github account:
# 1. CSV File (Ice Cream)
# 2. Excel File (Maven Business School)
# 3. JSON File (Drake)
# 4. Text File, add header 'English' and 'France' (eng-fra)
# 5. Web Dataset - https://raw.githubusercontent.com/michellechandraa/TutorDataMining/refs/heads/main/menu.csv
#
# convert the datasets into dataframe using github url.

# %%
# 1
iceCream = pd.read_csv('https://raw.githubusercontent.com/VickySav/Datasets/refs/heads/main/Ice%20Cream%20Sales%20and%20Temperature.csv')
iceCream.head()

# %%
# 2
mavenSchool = pd.read_excel('https://raw.githubusercontent.com/VickySav/Datasets/refs/heads/main/Maven%20Business%20School.xlsx')
mavenSchool.head()
# Out:
#    Student ID  Undergrad Degree  Undergrad Grade  MBA Grade Work Experience  \
# 0           1          Business             68.4       90.2              No
# 1           2          Business             62.1       92.8              No
# 2           3  Computer Science             70.2       68.7             Yes
# 3           4       Engineering             75.1       80.7              No
# 4           5           Finance             60.9       74.9              No
#
#    Employability (Before)  Employability (After)      Status  Annual Salary
# 0                   252.0                  276.0      Placed       111000.0
# 1                   423.0                  410.0  Not Placed            NaN
# 2                   101.0                  119.0      Placed       107000.0
# 3                   288.0                  334.0  Not Placed            NaN
# 4                   248.0                  252.0  Not Placed            NaN

# %%
# 3
drake = pd.read_json('https://raw.githubusercontent.com/VickySav/Datasets/refs/heads/main/drake_data.json')
drake.head()
# Out:
#                  album                           lyrics_title  \
# 0  Certified Lover Boy            Certified Lover Boy* Lyrics
# 1  Certified Lover Boy  Like I’m Supposed To/Do Things Lyrics
# 2  Certified Lover Boy                      Not Around Lyrics
# 3  Certified Lover Boy    In the Cut (Ft. Roddy Ricch) Lyrics
# 4  Certified Lover Boy  Zodiac Sign (Ft. Jessie Reyez) Lyrics
#
#                                           lyrics_url  \
# 0  https://genius.com/Drake-certified-lover-boy-l...
# 1  https://genius.com/Drake-like-im-supposed-to-d...
# 2         https://genius.com/Drake-not-around-lyrics
# 3         https://genius.com/Drake-in-the-cut-lyrics
# 4        https://genius.com/Drake-zodiac-sign-lyrics
#
#                                               lyrics track_views
# 0  Lyrics from CLB Merch\n\n[Verse]\nPut my feeli...        8.7K
# 1  [Verse]\nHands are tied\nSomeone's in my ear f...       38.8K
# 2  [Intro]\nYeah, we back\nWassup ladies?\nSwisha...      129.8K
# ...

# %%
# 4
engFra = pd.read_table('https://raw.githubusercontent.com/VickySav/Datasets/refs/heads/main/eng-fra.txt', delimiter='\t', header=None, names=['English', 'France'])
engFra.head()
engFra.sample(10)
# Out:
#                                  English  \
# 22793               Do you travel a lot?
# 24536               Is Tom still aboard?
# 36192             Whose is this bicycle?
# 39127            I've only seen it once.
# 88655  I want to ask you one last favor.
# 36187             Whose bicycle is this?
# 48318          I don't have any pencils.
# 50605          The students all laughed.
# 57983        Did someone follow us here?
# 83523   How long did you stay in Canada?
#
#                                            France
# 22793                     Voyagez-vous beaucoup ?
# 24536                  Tom est-il encore à bord ?
# 36192                         À qui est ce vélo ?
# 39127                  Je ne l'ai vu qu'une fois.
# 88655  Je veux vous demander une dernière faveur.
# 36187                      C’est à qui, ce vélo ?
# 48318                       Je n'ai aucun crayon.
# 50605                  Tous les étudiants rirent.
# 57983         Quelqu'un nous a-t-il suivies ici ?
# ...

# %%
# 5
webData = pd.read_csv(' https://raw.githubusercontent.com/michellechandraa/TutorDataMining/refs/heads/main/menu.csv')
webData.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# <h1> Try Yourself

# %% [markdown]
# a. Import MLBB HERO DATASET into dataframe <br>
# b. show 10 random data from dataset <br>
# c. Find out if there are any missing values in each column <br>
# d. drop the unnecessary column <br>
# e. show the roles of the hero in that dataset <br>
# f. show the most difficult hero to use<br>
# g. find out which ones has the average higher physical_atk between Fighters and Tank<br>
# output example: <br>
# "Fighters have higher average physical attack than Tanks." <br>
# "Tanks have higher average physical attack than Fighters." <br>
# "Fighters and Tanks have the same average physical attack." <br>
# h. Make a visualization showing percentages of heroes based on their role

# %%
# a
mlbb = pd.read_csv('https://raw.githubusercontent.com/VickySav/Datasets/refs/heads/main/mlbb_hero.csv', delimiter=';')
mlbb.head()
# Out:
#   hero_name      role  defense_overall  offense_overall  skill_effect_overall  \
# 0   Terizla   fighter              7.0              8.0                   6.0
# 1    Martis   fighter              6.0              8.0                   5.0
# 2     Grock      tank              8.0              5.0                   6.0
# 3  Carmilla   support              5.0              5.0                   9.0
# 4   Irithel  marksman              5.0              5.0                   8.0
#
#    difficulty_overall  movement_spd  magic_defense  mana  hp_regen  \
# 0                 6.0           255             10   430        54
# 1                 5.0           260             10     0        35
# 2                 4.0           260             10   430        42
# 3                 5.0           255             10   430        39
# 4                 7.0           260             10   438        35
#
#    physical_atk  physical_defense    hp  attack_speed  mana_regen  win_rate  \
# ...

# %%
# b
mlbb.sample(10)
# Out:
#    hero_name      role  defense_overall  offense_overall  \
# 89  Lancelot  assassin              6.0             10.0
# 47   Alucard   fighter              5.0              8.0
# 2      Grock      tank              8.0              5.0
# 43    Odette      mage              4.0              4.0
# 66    Claude  marksman              5.0              9.0
# 3   Carmilla   support              5.0              5.0
# 7      Lunox      mage              7.0              5.0
# 13    Karrie  marksman              3.0              9.0
# 69   Balmond   fighter              7.0              6.0
# 5     Thamuz   fighter              7.0              7.0
#
#     skill_effect_overall  difficulty_overall  movement_spd  magic_defense  \
# 89                   4.0                 7.0           260             10
# 47                   5.0                 5.0           260             10
# 2                    6.0                 4.0           260             10
# ...

# %%
# c
mlbb.isnull().sum()
# Out:
# hero_name                 0
# role                      0
# defense_overall           0
# offense_overall           0
# skill_effect_overall      0
# difficulty_overall        0
# movement_spd              0
# magic_defense             0
# mana                      0
# hp_regen                  0
# physical_atk              0
# physical_defense          0
# hp                        0
# attack_speed              0
# mana_regen                0
# win_rate                  0
# pick_rate                 0
# ban_rate                  0
# release_year              0
# Unnamed: 19             103
# dtype: int64

# %%
# d
mlbb.drop(columns=['Unnamed: 19'], inplace=True)
mlbb.head()
# Out:
#   hero_name      role  defense_overall  offense_overall  skill_effect_overall  \
# 0   Terizla   fighter              7.0              8.0                   6.0
# 1    Martis   fighter              6.0              8.0                   5.0
# 2     Grock      tank              8.0              5.0                   6.0
# 3  Carmilla   support              5.0              5.0                   9.0
# 4   Irithel  marksman              5.0              5.0                   8.0
#
#    difficulty_overall  movement_spd  magic_defense  mana  hp_regen  \
# 0                 6.0           255             10   430        54
# 1                 5.0           260             10     0        35
# 2                 4.0           260             10   430        42
# 3                 5.0           255             10   430        39
# 4                 7.0           260             10   438        35
#
#    physical_atk  physical_defense    hp  attack_speed  mana_regen  win_rate  \
# ...

# %%
# e
roles = mlbb['role'].unique()
print(roles)
# Out:
# ['fighter' 'tank' 'support' 'marksman' 'mage' 'assassin']

# %%
# f
most_difficult_hero = mlbb[mlbb['difficulty_overall'] == mlbb['difficulty_overall'].max()]
print("Most difficult hero to use is", most_difficult_hero['hero_name'].values[0])
# Out:
# Most difficult hero to use is Fanny

# %%
# g
physicalFighters = mlbb[mlbb['role'] == 'fighter']['physical_atk'].sum()
totalFighters = mlbb[mlbb['role'] == 'fighter']['physical_atk'].count()
physicalTanks = mlbb[mlbb['role'] == 'tank']['physical_atk'].sum()
totalTanks = mlbb[mlbb['role'] == 'tank']['physical_atk'].count()

avgFighters = physicalFighters / totalFighters
avgTanks = physicalTanks / totalTanks

print('Average physical attack for Fighters: ', avgFighters)
print('Average physical attack for Tanks: ', avgTanks)
if avgFighters > avgTanks:
  print('Fighters have higher average physical attack than Tanks.')
else:
    print('Tanks have higher average physical attack than Fighters.')
# Out:
# Average physical attack for Fighters:  119.96551724137932
# Average physical attack for Tanks:  119.53333333333333
# Fighters have higher average physical attack than Tanks.

# %%
# h
import matplotlib.pyplot as plt

y = mlbb['role'].value_counts()

plt.title("Percentage of Heroes by Role")
plt.pie(y, labels=y.index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# 7. I have a character with this specification:
# defense_overall 6.0<br>
# offense_overall 7.0<br>
# skill_effect_overall 4.0<br>
# difficulty_overall 3.0<br>
# movement_spd 250<br>
# magic_defense 9<br>
# mana 380<br>
# hp_regen 37<br>
# physical_atk 119<br>
# physical_defense 24<br>
# hp 2689<br>
# attack_speed 0.75<br>
# mana_regen 16.0<br>
#
# Please predict its role using DecisionTree classification algorithm <br>

# %%
# 7

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Encode the 'role' column
label_encoder = LabelEncoder()
mlbb['role_encoded'] = label_encoder.fit_transform(mlbb['role'])

# Separate features and target variable
x = mlbb[['defense_overall', 'offense_overall', 'skill_effect_overall', 'difficulty_overall', 'movement_spd', 'magic_defense', 'mana', 'hp_regen', 'physical_atk', 'physical_defense', 'hp', 'attack_speed', 'mana_regen']]
y = mlbb['role_encoded']

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3)

# Create a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model
clf.fit(x_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of the model:", accuracy)

# Predict the role for the given character
new_character = {
    'defense_overall': 6.0,
    'offense_overall': 7.0,
    'skill_effect_overall': 4.0,
    'difficulty_overall': 3.0,
    'movement_spd': 250,
    'magic_defense': 9,
    'mana': 380,
    'hp_regen': 37,
    'physical_atk': 119,
    'physical_defense': 24,
    'hp': 2689,
    'attack_speed': 0.75,
    'mana_regen': 16.0
}
new_character_df = pd.DataFrame([new_character])

predicted_role_encoded = clf.predict(new_character_df)

# Get the predicted role (dicoding)
predicted_role = label_encoder.inverse_transform(predicted_role_encoded)

print("Predicted role for the new character: ", predicted_role[0])
# Out:
# Accuracy of the model: 0.6666666666666666
# Predicted role for the new character:  fighter

# %% [markdown]
# 8. Why is CSV one of the most commonly used file formats in the field of data science? <br>

# %%
# 8
print('CSV is commonly used file because csv file is simple, lightweith, with great compatibility. It stores data in plain text, making it easy to read, share, and more efficient to handle large datasets. CSV also not requiring any special software to open, which makes it accessible to everyone.')

# https://chatgpt.com/share/66f5207d-792c-8010-a264-f64bd6ab8eca
# Out:
# CSV is commonly used file because csv file is simple, lightweith, with great compatibility. It stores data in plain text, making it easy to read, share, and more efficient to handle large datasets. CSV also not requiring any special software to open, which makes it accessible to everyone.
